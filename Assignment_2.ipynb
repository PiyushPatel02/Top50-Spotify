# %% [markdown]
# # Problem:1

# %%
import pandas as pd
import numpy as np

raw_data = pd.read_csv('top50spotify.csv')
raw_data
# Out:
#     SerialNo.                                         Track.Name  \
# 0           1                                           Señorita
# 1           2                                              China
# 2           3                      boyfriend (with Social House)
# 3           4                    Beautiful People (feat. Khalid)
# 4           5                        Goodbyes (Feat. Young Thug)
# 5           6                  I Don't Care (with Justin Bieber)
# 6           7                                             Ransom
# 7           8                                  How Do You Sleep?
# 8           9                              Old Town Road - Remix
# 9          10                                            bad guy
# 10         11                                           Callaita
# 11         12              Loco Contigo (feat. J. Balvin & Tyga)
# 12         13                                  Someone You Loved
# ...

# %%
df = pd.DataFrame(raw_data,columns = ['SerialNo.','Track.Name','Artist.Name','Genre','Energy','Length.','Popularity'])
print(df.head())
# Out:
#    SerialNo.                       Track.Name    Artist.Name           Genre  \
# 0          1                         Señorita   Shawn Mendes    canadian pop
# 1          2                            China       Anuel AA  reggaeton flow
# 2          3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3          4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4          5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Energy  Length.  Popularity
# 0      55      191          79
# 1      81      302          92
# 2      80      186          85
# 3      65      198          86
# 4      65      175          94

# %%
df.to_csv('top50.csv')
df.drop('SerialNo.',axis = 'columns')
# Out:
#                                            Track.Name       Artist.Name  \
# 0                                            Señorita      Shawn Mendes
# 1                                               China          Anuel AA
# 2                       boyfriend (with Social House)     Ariana Grande
# 3                     Beautiful People (feat. Khalid)        Ed Sheeran
# 4                         Goodbyes (Feat. Young Thug)       Post Malone
# 5                   I Don't Care (with Justin Bieber)        Ed Sheeran
# 6                                              Ransom         Lil Tecca
# 7                                   How Do You Sleep?         Sam Smith
# 8                               Old Town Road - Remix         Lil Nas X
# 9                                             bad guy     Billie Eilish
# 10                                           Callaita         Bad Bunny
# 11              Loco Contigo (feat. J. Balvin & Tyga)          DJ Snake
# ...

# %%
df2 = df[['Energy','Length.']].iloc[:10].mean()
df2
# Out:
# Energy      65.1
# Length.    195.6
# dtype: float64

# %%
print(df.groupby('Genre',as_index = True).groups)
# Out:
# {'atl hip hop': [33], 'australian pop': [26], 'big room': [35], 'boy band': [38], 'brostep': [45, 47], 'canadian hip hop': [14, 18, 27], 'canadian pop': [0, 25], 'country rap': [8, 21], 'dance pop': [2, 11, 15, 31, 34, 39, 41, 42], 'dfw rap': [4, 17], 'edm': [30, 40, 48], 'electropop': [9, 24], 'escape room': [19], 'latin': [16, 23, 28, 29, 46], 'panamanian pop': [13, 36], 'pop': [3, 5, 7, 12, 37, 43, 49], 'pop house': [20], 'r&b en espanol': [44], 'reggaeton': [10, 32], 'reggaeton flow': [1, 22], 'trap music': [6]}

# %%
df3 = df[['Length.']].sum()
df3
# Out:
# Length.    10048
# dtype: int64

# %%
df4 = df.groupby('Genre')['Artist.Name'].aggregate(['max'])
print(df4.shape)
df4
# Out:
# (21, 1)
#                                max
# Genre
# atl hip hop             Young Thug
# australian pop         Tones and I
# big room             Martin Garrix
# boy band            Jonas Brothers
# brostep                 Marshmello
# canadian hip hop               Y2K
# canadian pop          Shawn Mendes
# country rap              Lil Nas X
# dance pop             Taylor Swift
# dfw rap                Post Malone
# edm               The Chainsmokers
# electropop           Billie Eilish
# escape room                  Lizzo
# latin                    Nicky Jam
# panamanian pop                Sech
# pop                      Sam Smith
# pop house                   MEDUZA
# r&b en espanol             ROSALÍA
# reggaeton                   Maluma
# reggaeton flow         Jhay Cortez
# trap music               Lil Tecca

# %%
df4.to_csv('TopArtist.csv')
data2 = pd.read_csv('TopArtist.csv', index_col = 'Genre')

# %% [markdown]
# # Problem:2

# %%
dict = {'English':{'Sam':60,'Jackson':74,'Ahree':85}, 
        'History':{'Gloria':83,'Sam':65,'Isla':78,'Aron':72,'Gray':61},
        'Geography':{'Jackson':92,'Gloria':95,'Isla':82,'Aron':75,'Ahree':76},
        'Mathematics':{'Sam':99,'Gloria':74,'Jackson':89,'Ahree':85,'Gray':95},
        'Science':{'Sam':89,'Aron':82,'Gray':78,'Isla':93,'Ahree':87}}

series = pd.Series(dict)
series

df = pd.DataFrame(dict)
df
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        NaN         99.0     89.0
# Jackson     74.0      NaN       92.0         89.0      NaN
# Ahree       85.0      NaN       76.0         85.0     87.0
# Gloria       NaN     83.0       95.0         74.0      NaN
# Isla         NaN     78.0       82.0          NaN     93.0
# Aron         NaN     72.0       75.0          NaN     82.0
# Gray         NaN     61.0        NaN         95.0     78.0

# %%
df2 = df.fillna(0)
df2
# Out:
#          English  History  Geography  Mathematics  Science
# Sam         60.0     65.0        0.0         99.0     89.0
# Jackson     74.0      0.0       92.0         89.0      0.0
# Ahree       85.0      0.0       76.0         85.0     87.0
# Gloria       0.0     83.0       95.0         74.0      0.0
# Isla         0.0     78.0       82.0          0.0     93.0
# Aron         0.0     72.0       75.0          0.0     82.0
# Gray         0.0     61.0        0.0         95.0     78.0

# %%
df2['Average'] = df2.mean(numeric_only = True ,axis=1)
df2
# Out:
#          English  History  Geography  Mathematics  Science  Average
# Sam         60.0     65.0        0.0         99.0     89.0     62.6
# Jackson     74.0      0.0       92.0         89.0      0.0     51.0
# Ahree       85.0      0.0       76.0         85.0     87.0     66.6
# Gloria       0.0     83.0       95.0         74.0      0.0     50.4
# Isla         0.0     78.0       82.0          0.0     93.0     50.6
# Aron         0.0     72.0       75.0          0.0     82.0     45.8
# Gray         0.0     61.0        0.0         95.0     78.0     46.8

# %%
df3 = df2.transpose()
df3
# Out:
#               Sam  Jackson  Ahree  Gloria  Isla  Aron  Gray
# English      60.0     74.0   85.0     0.0   0.0   0.0   0.0
# History      65.0      0.0    0.0    83.0  78.0  72.0  61.0
# Geography     0.0     92.0   76.0    95.0  82.0  75.0   0.0
# Mathematics  99.0     89.0   85.0    74.0   0.0   0.0  95.0
# Science      89.0      0.0   87.0     0.0  93.0  82.0  78.0
# Average      62.6     51.0   66.6    50.4  50.6  45.8  46.8

# %% [markdown]
# # Problem:3

# %%
for i in range(1,1001):
    if((i%7==0)&(i%17==0)):
        print(i)
# Out:
# 119
# 238
# 357
# 476
# 595
# 714
# 833
# 952

# %% [markdown]
# # Problem:4

# %%
supMar = pd.read_csv('cereal.csv')
supMar
df = pd.DataFrame(supMar)
df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
df.pivot(index="mfr",columns="name",values="rating")
# Out:
# name  100% Bran  100% Natural Bran   All-Bran  All-Bran with Extra Fiber  \
# mfr
# A           NaN                NaN        NaN                        NaN
# G           NaN                NaN        NaN                        NaN
# K           NaN                NaN  59.425505                  93.704912
# N     68.402973                NaN        NaN                        NaN
# P           NaN                NaN        NaN                        NaN
# Q           NaN          33.983679        NaN                        NaN
# R           NaN                NaN        NaN                        NaN
#
# name  Almond Delight  Apple Cinnamon Cheerios  Apple Jacks    Basic 4  \
# mfr
# A                NaN                      NaN          NaN        NaN
# G                NaN                29.509541          NaN  37.038562
# K                NaN                      NaN    33.174094        NaN
# N                NaN                      NaN          NaN        NaN
# ...

# %%
import matplotlib.pyplot as plt
df=  pd.DataFrame(supMar,columns=['rating','mfr'])
df.plot(x='mfr',y='rating',
       kind='line')
plt.xticks(np.arange(0,100))
plt.show();

# %%
import seaborn as sns
